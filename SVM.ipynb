# %%
from sklearn.datasets import load_iris
import pandas as pd
iris = load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.feature_names
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df['target'] = iris.target
df['target names'] = df.target.apply(lambda x: iris.target_names[x])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target target names
# 0         0       setosa
# 1         0       setosa
# 2         0       setosa
# 3         0       setosa
# 4         0       setosa
# ..      ...          ...
# 145       2    virginica
# 146       2    virginica
# 147       2    virginica
# 148       2    virginica
# 149       2    virginica
#
# [150 rows x 6 columns]

# %%
target = df.target
input = df.drop(['target','target names'],axis='columns')
input
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df0 = df[df.target==0]
df1 = df[df.target==1]
df2 = df[df.target==2]

# %%
from matplotlib import pyplot as plt
plt.scatter(df0['sepal length (cm)'],df0['sepal width (cm)'],color='green',marker='+')
plt.scatter(df1['sepal length (cm)'],df1['sepal width (cm)'],color='blue',marker='+')
# plt.scatter(df2['sepal length (cm)'],df2['sepal width (cm)'],color='red',marker='+')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(input,target,test_size=0.2)

# %%
len(X_train)
# Out:
# 120

# %%
X_test
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 134                6.1               2.6                5.6               1.4
# 55                 5.7               2.8                4.5               1.3
# 9                  4.9               3.1                1.5               0.1
# 136                6.3               3.4                5.6               2.4
# 8                  4.4               2.9                1.4               0.2
# 88                 5.6               3.0                4.1               1.3
# 25                 5.0               3.0                1.6               0.2
# 72                 6.3               2.5                4.9               1.5
# 83                 6.0               2.7                5.1               1.6
# 52                 6.9               3.1                4.9               1.5
# 35                 5.0               3.2                1.2               0.2
# 127                6.1               3.0                4.9               1.8
# 28                 5.2               3.4                1.4               0.2
# 69                 5.6               2.5                3.9               1.1
# 16                 5.4               3.9                1.3               0.4
# 76                 6.8               2.8                4.8               1.4
# 97                 6.2               2.9                4.3               1.3
# 141                6.9               3.1                5.1               2.3
# 18                 5.7               3.8                1.7               0.3
# 23                 5.1               3.3                1.7               0.5
# 27                 5.2               3.5                1.5               0.2
# 117                7.7               3.8                6.7               2.2
# 128                6.4               2.8                5.6               2.1
# 67                 5.8               2.7                4.1               1.0
# 138                6.0               3.0                4.8               1.8
# 46                 5.1               3.8                1.6               0.2
# 2                  4.7               3.2                1.3               0.2
# 66                 5.6               3.0                4.5               1.5
# 133                6.3               2.8                5.1               1.5
# 45                 4.8               3.0                1.4               0.3

# %%
from sklearn.svm import SVC
model = SVC(kernel='poly')

# %%
model.fit(X_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
model.score(X_test,y_test)
# Out:
# 0.9333333333333333

# %%
model.predict(X_test)
# Out:
# array([2, 1, 0, 2, 0, 1, 0, 2, 2, 1, 0, 2, 0, 1, 0, 1, 1, 2, 0, 0, 0, 2,
#        2, 1, 2, 0, 0, 1, 2, 0])
